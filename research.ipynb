# %%
GEMINI_API_KEY = "AIzaSyCEA988TAwcEeZeKvD8aJGgEBKSP2leP_g"

# %%
import google.generativeai as genai
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import google.generativeai as genai
#
# ModuleNotFoundError: No module named 'google'

# %%
GEMINI_API_KEY = "AIzaSyCEA988TAwcEeZeKvD8aJGgEBKSP2leP_g"
genai.configure(api_key=GEMINI_API_KEY) 

model = genai.GenerativeModel("gemini-2.5-flash")

# %%
user_input = "What is Python?"

prompt = f"Answar the provided question in short, Question: {user_input}"

response = model.generate_content(prompt)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       1 user_input = "What is Python?"
#       3 prompt = f"Answar the provided question in short, Question: {user_input}"
# ----> 5 response = model.generate_content(prompt)
#       6 print(response.text)
#
# NameError: name 'model' is not defined
